# %%
import os;
import io;
import pandas as pd; 
import gzip

files = os.listdir()

for files in files:
    if (files.endswith('.txt')):
        clinical = pd.read_csv(files, sep = '\t')
        print(clinical.head(10))
# Out:
#              sample       patient                       barcode  \
# 0  TCGA-OR-A5K6-01A  TCGA-OR-A5K6  TCGA-OR-A5K6-01A-11R-A29S-07
# 1  TCGA-OR-A5LP-01A  TCGA-OR-A5LP  TCGA-OR-A5LP-01A-11R-A29S-07
# 2  TCGA-OR-A5J2-01A  TCGA-OR-A5J2  TCGA-OR-A5J2-01A-11R-A29S-07
# 3  TCGA-OR-A5LT-01A  TCGA-OR-A5LT  TCGA-OR-A5LT-01A-11R-A29S-07
# 4  TCGA-OR-A5JI-01A  TCGA-OR-A5JI  TCGA-OR-A5JI-01A-11R-A29S-07
# 5  TCGA-OR-A5L9-01A  TCGA-OR-A5L9  TCGA-OR-A5L9-01A-11R-A29S-07
# 6  TCGA-OR-A5LC-01A  TCGA-OR-A5LC  TCGA-OR-A5LC-01A-11R-A29S-07
# 7  TCGA-OR-A5LO-01A  TCGA-OR-A5LO  TCGA-OR-A5LO-01A-11R-A29S-07
# 8  TCGA-OR-A5K1-01A  TCGA-OR-A5K1  TCGA-OR-A5K1-01A-11R-A29S-07
# 9  TCGA-OR-A5LS-01A  TCGA-OR-A5LS  TCGA-OR-A5LS-01A-11R-A29S-07
#
#   shortLetterCode           definition classification_of_tumor  \
# 0              TP  Primary solid Tumor            not reported
# 1              TP  Primary solid Tumor            not reported
# 2              TP  Primary solid Tumor            not reported
# 3              TP  Primary solid Tumor            not reported
# 4              TP  Primary solid Tumor            not reported
# 5              TP  Primary solid Tumor            not reported
# 6              TP  Primary solid Tumor            not reported
# 7              TP  Primary solid Tumor            not reported
# 8              TP  Primary solid Tumor            not reported
# 9              TP  Primary solid Tumor            not reported
#
#   last_known_disease_status                updated_datetime.x  \
# 0              not reported  2018-03-09T16:42:15.753583-06:00
# 1              not reported  2018-03-09T16:42:15.753583-06:00
# 2              not reported  2018-03-09T16:42:15.753583-06:00
# 3              not reported  2018-03-09T16:42:15.753583-06:00
# 4              not reported  2018-03-09T16:42:15.753583-06:00
# 5              not reported  2018-03-09T16:42:15.753583-06:00
# 6              not reported  2018-03-09T16:42:15.753583-06:00
# 7              not reported  2018-03-09T16:42:15.753583-06:00
# 8              not reported  2018-03-09T16:42:15.753583-06:00
# 9              not reported  2018-03-09T16:42:15.753583-06:00
#
#   primary_diagnosis tumor_stage     ...      subtype_MethyLevel  \
# 0             C74.0    stage ii     ...       CIMP-intermediate
# 1             C74.0    stage ii     ...                CIMP-low
# 2             C74.0    stage iv     ...                CIMP-low
# 3             C74.0   stage iii     ...       CIMP-intermediate
# 4             C74.0     stage i     ...       CIMP-intermediate
# 5             C74.0    stage ii     ...                CIMP-low
# 6             C74.0    stage iv     ...       CIMP-intermediate
# 7             C74.0    stage ii     ...               CIMP-high
# 8             C74.0    stage ii     ...                CIMP-low
# 9             C74.0    stage ii     ...       CIMP-intermediate
#
#   subtype_miRNA.cluster subtype_SCNA.cluster  subtype_protein.cluster  \
# 0               miRNA_1                Noisy                      3.0
# 1               miRNA_6          Chromosomal                      2.0
# 2               miRNA_1                Noisy                      1.0
# 3               miRNA_5          Chromosomal                      2.0
# 4               miRNA_2          Chromosomal                      NaN
# 5               miRNA_1          Chromosomal                      NaN
# 6               miRNA_1          Chromosomal                      NaN
# 7               miRNA_4          Chromosomal                      1.0
# 8               miRNA_5          Chromosomal                      2.0
# 9               miRNA_6          Chromosomal                      1.0
#
#    subtype_COC  subtype_OncoSign subtype_purity  subtype_ploidy  \
# 0         COC3            CTNNB1           0,91            1,91
# 1         COC1          TP53/NF1           0,76            1,28
# 2         COC3          TP53/NF1           0,89            1,31
# 3         COC1          TP53/NF1           0,92            2,78
# 4         COC2      Unclassified              1            4,88
# 5         COC1      Unclassified           0,82            1,26
# 6         COC2        TERT/ZNRF3            0,9            3,32
# 7         COC3        TERT/ZNRF3           0,88            2,72
# 8         COC1      Unclassified           0,89            1,26
# 9         COC2        TERT/ZNRF3           0,84            2,99
#
#   subtype_genome_doublings subtype_ADS
# 0                      0.0        1,28
# 1                      0.0       -0,66
# 2                      0.0       -0,84
# 3                      1.0       -1,46
# 4                      2.0       -0,70
# 5                      0.0       -0,61
# 6                      1.0        0,76
# 7                      1.0       -0,41
# 8                      0.0       -0,13
# 9                      1.0        0,48
#
# [10 rows x 71 columns]
#              sample       patient                       barcode  \
# 0  TCGA-E2-A15D-01A  TCGA-E2-A15D  TCGA-E2-A15D-01A-11R-A115-07
# 1  TCGA-C8-A131-01A  TCGA-C8-A131  TCGA-C8-A131-01A-11R-A115-07
# 2  TCGA-BH-A18L-01A  TCGA-BH-A18L  TCGA-BH-A18L-01A-32R-A12D-07
# 3  TCGA-B6-A0X4-01A  TCGA-B6-A0X4  TCGA-B6-A0X4-01A-11R-A109-07
# 4  TCGA-BH-A0BF-01A  TCGA-BH-A0BF  TCGA-BH-A0BF-01A-21R-A12P-07
# 5  TCGA-A8-A0AB-01A  TCGA-A8-A0AB  TCGA-A8-A0AB-01A-11R-A034-07
# 6  TCGA-AN-A0AS-01A  TCGA-AN-A0AS  TCGA-AN-A0AS-01A-11R-A00Z-07
# 7  TCGA-AN-A0FT-01A  TCGA-AN-A0FT  TCGA-AN-A0FT-01A-11R-A034-07
# 8  TCGA-AR-A1AT-01A  TCGA-AR-A1AT  TCGA-AR-A1AT-01A-11R-A12P-07
# 9  TCGA-AN-A0FV-01A  TCGA-AN-A0FV  TCGA-AN-A0FV-01A-11R-A00Z-07
#
#   shortLetterCode           definition classification_of_tumor  \
# 0              TP  Primary solid Tumor            not reported
# 1              TP  Primary solid Tumor            not reported
# 2              TP  Primary solid Tumor            not reported
# 3              TP  Primary solid Tumor            not reported
# 4              TP  Primary solid Tumor            not reported
# 5              TP  Primary solid Tumor            not reported
# 6              TP  Primary solid Tumor            not reported
# 7              TP  Primary solid Tumor            not reported
# 8              TP  Primary solid Tumor            not reported
# 9              TP  Primary solid Tumor            not reported
#
#   last_known_disease_status                updated_datetime.x  \
# 0              not reported  2018-03-09T16:42:15.753583-06:00
# 1              not reported  2018-03-09T16:42:15.753583-06:00
# 2              not reported  2018-03-09T16:42:15.753583-06:00
# 3              not reported  2018-03-09T16:42:15.753583-06:00
# 4              not reported  2018-03-09T16:42:15.753583-06:00
# 5              not reported  2018-03-09T16:42:15.753583-06:00
# 6              not reported  2018-03-09T16:42:15.753583-06:00
# 7              not reported  2018-03-09T16:42:15.753583-06:00
# 8              not reported  2018-03-09T16:42:15.753583-06:00
# 9              not reported  2018-03-09T16:42:15.753583-06:00
#
#   primary_diagnosis tumor_stage           ...             \
# 0             C50.9   stage iia           ...
# 1             C50.9  stage iiia           ...
# 2             C50.9  stage iiia           ...
# 3             C50.9   stage iib           ...
# 4             C50.9   stage iib           ...
# 5             C50.9   stage iia           ...
# 6             C50.9  stage iiia           ...
# 7             C50.9   stage iib           ...
# 8             C50.9   stage iia           ...
# 9             C50.9   stage iia           ...
#
#    subtype_tobacco_smoking_history subtype_CNV.Clusters  \
# 0                              NaN                   C1
# 1                              NaN                   C4
# 2                              NaN                   C6
# 3                              NaN                  NaN
# 4                              NaN                   C4
# 5                              NaN                   C1
# 6                              NaN                   C6
# 7                              NaN                   C4
# 8                              NaN                  NaN
# 9                              NaN                   C3
#
#   subtype_Mutation.Clusters  subtype_DNA.Methylation.Clusters  \
# 0                        C4                                C1
# 1                        C7                                C2
# 2                        C1                                C1
# 3                        C4                                C1
# 4                        C1                                C1
# 5                        C4                                C1
# 6                        C4                                C1
# 7                        C4                                C2
# 8                        C1                                C2
# 9                        C9                                C4
#
#    subtype_mRNA.Clusters  subtype_miRNA.Clusters subtype_lncRNA.Clusters  \
# 0                     C1                      C3                      C2
# 1                     C2                      C7                      C1
# 2                     C1                      C3                      C2
# 3                     C1                      C3                     NaN
# 4                     C2                      C3                      C2
# 5                     C1                      C3                     NaN
# 6                     C1                      C3                      C3
# 7                     C2                      C7                      C2
# 8                     C1                      C3                     NaN
# 9                     C2                      C3                      C1
#
#    subtype_Protein.Clusters subtype_PARADIGM.Clusters subtype_Pan.Gyn.Clusters
# 0                        C1                        C5                       C1
# 1                        C5                        C4                       C3
# 2                        C1                        C5                       C5
# 3                       NaN                        C5                      NaN
# 4                        C1                        C6                       C3
# 5                       NaN                        C5                      NaN
# 6                        C1                        C5                       C5
# 7                        C1                        C8                       C4
# 8                        C1                       NaN                       C3
# 9                        C1                        C5                       C4
#
# [10 rows x 81 columns]
#              sample       patient                       barcode  \
# 0  TCGA-AB-2966-03A  TCGA-AB-2966  TCGA-AB-2966-03A-01T-0734-13
# 1  TCGA-AB-2950-03A  TCGA-AB-2950  TCGA-AB-2950-03A-01T-0735-13
# 2  TCGA-AB-2871-03A  TCGA-AB-2871  TCGA-AB-2871-03A-01T-0735-13
# 3  TCGA-AB-2976-03A  TCGA-AB-2976  TCGA-AB-2976-03A-01T-0734-13
# 4  TCGA-AB-2939-03A  TCGA-AB-2939  TCGA-AB-2939-03A-01T-0740-13
# 5  TCGA-AB-2899-03A  TCGA-AB-2899  TCGA-AB-2899-03A-01T-0736-13
# 6  TCGA-AB-2877-03A  TCGA-AB-2877  TCGA-AB-2877-03A-01T-0735-13
# 7  TCGA-AB-2839-03A  TCGA-AB-2839  TCGA-AB-2839-03A-01T-0734-13
# 8  TCGA-AB-2928-03A  TCGA-AB-2928  TCGA-AB-2928-03A-01T-0740-13
# 9  TCGA-AB-2937-03A  TCGA-AB-2937  TCGA-AB-2937-03A-01T-0734-13
#
#   shortLetterCode                                       definition  \
# 0              TB  Primary Blood Derived Cancer - Peripheral Blood
# 1              TB  Primary Blood Derived Cancer - Peripheral Blood
# 2              TB  Primary Blood Derived Cancer - Peripheral Blood
# 3              TB  Primary Blood Derived Cancer - Peripheral Blood
# 4              TB  Primary Blood Derived Cancer - Peripheral Blood
# 5              TB  Primary Blood Derived Cancer - Peripheral Blood
# 6              TB  Primary Blood Derived Cancer - Peripheral Blood
# 7              TB  Primary Blood Derived Cancer - Peripheral Blood
# 8              TB  Primary Blood Derived Cancer - Peripheral Blood
# 9              TB  Primary Blood Derived Cancer - Peripheral Blood
#
#   classification_of_tumor last_known_disease_status  \
# 0            not reported              not reported
# 1            not reported              not reported
# 2            not reported              not reported
# 3            not reported              not reported
# 4            not reported              not reported
# 5            not reported              not reported
# 6            not reported              not reported
# 7            not reported              not reported
# 8            not reported              not reported
# 9            not reported              not reported
#
#                  updated_datetime.x primary_diagnosis   tumor_stage   ...    \
# 0  2018-03-16T17:58:18.620738-05:00      not reported  not reported   ...
# 1  2018-03-16T17:58:18.620738-05:00      not reported  not reported   ...
# 2  2018-03-16T17:58:18.620738-05:00      not reported  not reported   ...
# 3  2018-03-16T17:58:18.620738-05:00      not reported  not reported   ...
# 4  2018-03-16T17:58:18.620738-05:00      not reported  not reported   ...
# 5  2018-03-16T17:58:18.620738-05:00      not reported  not reported   ...
# 6  2018-03-16T17:58:18.620738-05:00      not reported  not reported   ...
# 7  2018-03-16T17:58:18.620738-05:00      not reported  not reported   ...
# 8  2018-03-16T17:58:18.620738-05:00      not reported  not reported   ...
# 9  2018-03-16T17:58:18.620738-05:00      not reported  not reported   ...
#
#    bcr_patient_barcode dbgap_accession_number            disease_type  \
# 0         TCGA-AB-2966                    NaN  Acute Myeloid Leukemia
# 1         TCGA-AB-2950                    NaN  Acute Myeloid Leukemia
# 2         TCGA-AB-2871                    NaN  Acute Myeloid Leukemia
# 3         TCGA-AB-2976                    NaN  Acute Myeloid Leukemia
# 4         TCGA-AB-2939                    NaN  Acute Myeloid Leukemia
# 5         TCGA-AB-2899                    NaN  Acute Myeloid Leukemia
# 6         TCGA-AB-2877                    NaN  Acute Myeloid Leukemia
# 7         TCGA-AB-2839                    NaN  Acute Myeloid Leukemia
# 8         TCGA-AB-2928                    NaN  Acute Myeloid Leukemia
# 9         TCGA-AB-2937                    NaN  Acute Myeloid Leukemia
#
#    releasable  released  state.1 primary_site  project_id  \
# 0       False      True     open  Bone Marrow   TCGA-LAML
# 1       False      True     open  Bone Marrow   TCGA-LAML
# 2       False      True     open  Bone Marrow   TCGA-LAML
# 3       False      True     open  Bone Marrow   TCGA-LAML
# 4       False      True     open  Bone Marrow   TCGA-LAML
# 5       False      True     open  Bone Marrow   TCGA-LAML
# 6       False      True     open  Bone Marrow   TCGA-LAML
# 7       False      True     open  Bone Marrow   TCGA-LAML
# 8       False      True     open  Bone Marrow   TCGA-LAML
# 9       False      True     open  Bone Marrow   TCGA-LAML
#
#                      name is_ffpe
# 0  Acute Myeloid Leukemia   False
# 1  Acute Myeloid Leukemia   False
# 2  Acute Myeloid Leukemia   False
# 3  Acute Myeloid Leukemia   False
# 4  Acute Myeloid Leukemia   False
# 5  Acute Myeloid Leukemia   False
# 6  Acute Myeloid Leukemia   False
# 7  Acute Myeloid Leukemia   False
# 8  Acute Myeloid Leukemia   False
# 9  Acute Myeloid Leukemia   False
#
# [10 rows x 57 columns]
#              sample       patient                       barcode  \
# 0  TCGA-EE-A2MG-06A  TCGA-EE-A2MG  TCGA-EE-A2MG-06A-11R-A18T-07
# 1  TCGA-EE-A3JD-06A  TCGA-EE-A3JD  TCGA-EE-A3JD-06A-11R-A20F-07
# 2  TCGA-D3-A5GL-06A  TCGA-D3-A5GL  TCGA-D3-A5GL-06A-11R-A27Q-07
# 3  TCGA-EE-A2MU-06A  TCGA-EE-A2MU  TCGA-EE-A2MU-06A-21R-A18S-07
# 4  TCGA-D3-A3CF-06A  TCGA-D3-A3CF  TCGA-D3-A3CF-06A-11R-A18T-07
# 5  TCGA-EE-A2M8-06A  TCGA-EE-A2M8  TCGA-EE-A2M8-06A-12R-A18S-07
# 6  TCGA-EE-A2GL-06A  TCGA-EE-A2GL  TCGA-EE-A2GL-06A-11R-A18S-07
# 7  TCGA-GN-A268-06A  TCGA-GN-A268  TCGA-GN-A268-06A-11R-A18T-07
# 8  TCGA-EE-A29T-06A  TCGA-EE-A29T  TCGA-EE-A29T-06A-11R-A18T-07
# 9  TCGA-FS-A1ZK-06A  TCGA-FS-A1ZK  TCGA-FS-A1ZK-06A-11R-A18T-07
#
#   shortLetterCode  definition classification_of_tumor  \
# 0              TM  Metastatic            not reported
# 1              TM  Metastatic            not reported
# 2              TM  Metastatic            not reported
# 3              TM  Metastatic            not reported
# 4              TM  Metastatic            not reported
# 5              TM  Metastatic            not reported
# 6              TM  Metastatic            not reported
# 7              TM  Metastatic            not reported
# 8              TM  Metastatic            not reported
# 9              TM  Metastatic            not reported
#
#   last_known_disease_status                updated_datetime.x  \
# 0              not reported  2018-03-09T16:42:15.753583-06:00
# 1              not reported  2018-03-09T16:42:15.753583-06:00
# 2              not reported  2018-03-09T16:42:15.753583-06:00
# 3              not reported  2018-03-09T16:42:15.753583-06:00
# 4              not reported  2018-03-09T16:42:15.753583-06:00
# 5              not reported  2018-03-09T16:42:15.753583-06:00
# 6              not reported  2018-03-09T16:42:15.753583-06:00
# 7              not reported  2018-03-09T16:42:15.753583-06:00
# 8              not reported  2018-03-09T16:42:15.753583-06:00
# 9              not reported  2018-03-09T16:42:15.753583-06:00
#
#   primary_diagnosis   tumor_stage                   ...                     \
# 0             C77.3       stage i                   ...
# 1             C77.3     stage iii                   ...
# 2             C77.3      stage ib                   ...
# 3             C49.1      stage ia                   ...
# 4             C77.4    stage iiic                   ...
# 5             C77.4     stage iii                   ...
# 6             C77.3     stage iia                   ...
# 7             C77.3     stage iib                   ...
# 8             C77.9  not reported                   ...
# 9             C44.9      stage ii                   ...
#
#    subtype_CURATED_DISTANT_ANATOMIC_SITE subtype_CURATED_VITAL_STATUS  \
# 0                                    NaN                          NaN
# 1                                    NaN                          NaN
# 2                                    NaN                          NaN
# 3                                    NaN                          NaN
# 4                                    NaN                          NaN
# 5                                    NaN                          NaN
# 6                                    NaN                          NaN
# 7                                    NaN                          NaN
# 8                                    NaN                          NaN
# 9                                    NaN                          NaN
#
#   subtype_CURATED_DAYS_TO_DEATH_OR_LAST_FU  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
#
#    subtype_CURATED_TCGA_DAYS_TO_DEATH_OR_LAST_FU  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                                            NaN
#
#    subtype_CURATED_MELANOMA_SPECIFIC_VITAL_STATUS..0....ALIVE.OR.CENSORED...1....DEAD.OF.MELANOMA..  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    subtype_CURATED_TCGA_SPECIMEN_Distant subtype_CC.TT.nTotal.Mut  \
# 0                                    NaN                      NaN
# 1                                    NaN                      NaN
# 2                                    NaN                      NaN
# 3                                    NaN                      NaN
# 4                                    NaN                      NaN
# 5                                    NaN                      NaN
# 6                                    NaN                      NaN
# 7                                    NaN                      NaN
# 8                                    NaN                      NaN
# 9                                    NaN                      NaN
#
#    subtype_DIPYRIM.C.T.nTotal.Mut subtype_DIPYRIM.C.T.n.C.T..mut  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
# 5                             NaN                            NaN
# 6                             NaN                            NaN
# 7                             NaN                            NaN
# 8                             NaN                            NaN
# 9                             NaN                            NaN
#
#   subtype_SHATTERSEEK_Chromothripsis_calls
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
#
# [10 rows x 169 columns]

# %%
#number of rows
print(clinical.shape[0])

#number of columms
print(clinical.shape[1])

#number of unique patients
patient = clinical[['patient']]
patient.nunique()
# Out:
# 472
# 169
# patient    468
# dtype: int64

# %%
clinical_short = clinical[['patient' , 'year_of_birth' , 'gender' , 'race' , 'definition' , 'tumor_stage'  , 'age_at_diagnosis' , 'vital_status' , 'days_to_death', 'days_to_last_follow_up']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-101-26311c0f2c6e> in <module>
# ----> 1 clinical_short = clinical[['patient' , 'year_of_birth' , 'gender' , 'race' , 'definition' , 'tumor_stage'  , 'age_at_diagnosis' , 'vital_status' , 'days_to_death', 'days_to_last_follow_up' , 'diagnosis' ]]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "['days_to_death' 'days_to_last_follow_up' 'diagnosis'] not in index"

# %%
#checking my sanity... it's there!
clinical_short.head()
# Out:
#         patient  year_of_birth  gender   race  definition tumor_stage  \
# 0  TCGA-EE-A2MG         1974.0    male  white  Metastatic     stage i
# 1  TCGA-EE-A3JD         1939.0    male  white  Metastatic   stage iii
# 2  TCGA-D3-A5GL         1929.0    male  white  Metastatic    stage ib
# 3  TCGA-EE-A2MU         1934.0    male  white  Metastatic    stage ia
# 4  TCGA-D3-A3CF         1948.0  female  white  Metastatic  stage iiic
#
#    age_at_diagnosis vital_status  days_to_death  days_to_last_follow_up
# 0            8405.0         dead         3139.0                     NaN
# 1           25930.0         dead          832.0                     NaN
# 2           27095.0        alive            NaN                  3826.0
# 3           26237.0        alive            NaN                  1620.0
# 4           22409.0         dead          746.0                     NaN

# %%
#convert age_at_diagnosis from days to years, round to nearest hundredth and overwrite original values -- don't really know why this needs to be added, but it doesn't run without it. 
pd.options.mode.chained_assignment = None  # default='warn'


age_messing = clinical_short['age_at_diagnosis']/365
clinical_short['age_at_diagnosis'] = round(age_messing , 2)

# %%
dead = clinical_short['days_to_death']/12
clinical_short['days_to_death'] = round(dead , 2)

# %%
doctorz_visit = clinical_short['days_to_last_follow_up']/12
clinical_short['days_to_last_follow_up'] = round(doctorz_visit , 2)

# %%
clinical_short.rename(columns = {'days_to_death':'months_to_death' , "days_to_last_follow_up": "months_to_last_follow_up"} , inplace = True)

# %%
#let's do another sanity check
clinical_short
# Out:
#           patient  year_of_birth  gender          race             definition  \
# 0    TCGA-EE-A2MG         1974.0    male         white             Metastatic
# 1    TCGA-EE-A3JD         1939.0    male         white             Metastatic
# 2    TCGA-D3-A5GL         1929.0    male         white             Metastatic
# 3    TCGA-EE-A2MU         1934.0    male         white             Metastatic
# 4    TCGA-D3-A3CF         1948.0  female         white             Metastatic
# 5    TCGA-EE-A2M8         1946.0  female         white             Metastatic
# 6    TCGA-EE-A2GL         1966.0  female         white             Metastatic
# 7    TCGA-GN-A268         1922.0  female         white             Metastatic
# 8    TCGA-EE-A29T         1931.0  female         white             Metastatic
# 9    TCGA-FS-A1ZK         1937.0    male         white             Metastatic
# 10   TCGA-EE-A2MS         1927.0    male         white             Metastatic
# 11   TCGA-D3-A2J9         1928.0    male         white             Metastatic
# 12   TCGA-D3-A3CC         1936.0  female         white             Metastatic
# 13   TCGA-BF-A5ES         1936.0  female         white    Primary solid Tumor
# 14   TCGA-EB-A41A         1922.0    male         white    Primary solid Tumor
# 15   TCGA-EB-A97M         1947.0    male         white    Primary solid Tumor
# 16   TCGA-EE-A2A1         1958.0    male         white             Metastatic
# 17   TCGA-EE-A183         1959.0    male         white             Metastatic
# 18   TCGA-D3-A3MV         1972.0  female         white             Metastatic
# 19   TCGA-3N-A9WC         1927.0    male         white             Metastatic
# 20   TCGA-WE-A8K4         1928.0    male         white    Primary solid Tumor
# 21   TCGA-D9-A4Z2         1962.0    male         white    Primary solid Tumor
# 22   TCGA-DA-A95Y         1944.0    male         white             Metastatic
# 23   TCGA-ER-A19J         1950.0    male         white             Metastatic
# 24   TCGA-D3-A5GR         1975.0  female         white             Metastatic
# 25   TCGA-WE-A8K6         1934.0    male         white             Metastatic
# 26   TCGA-GF-A6C8         1950.0  female         white             Metastatic
# 27   TCGA-BF-A9VF         1936.0    male         white    Primary solid Tumor
# 28   TCGA-D3-A1QA         1950.0    male         white  Additional Metastatic
# 29   TCGA-EB-A551         1934.0  female         white    Primary solid Tumor
# ..            ...            ...     ...           ...                    ...
# 442  TCGA-ER-A19T         1955.0    male         white             Metastatic
# 443  TCGA-FR-A7U9         1950.0  female         white             Metastatic
# 444  TCGA-EE-A2GH         1962.0    male         white             Metastatic
# 445  TCGA-HR-A2OH            NaN  female  not reported             Metastatic
# 446  TCGA-WE-A8ZN         1952.0    male  not reported             Metastatic
# 447  TCGA-BF-AAP0         1973.0  female         white             Metastatic
# 448  TCGA-W3-AA1W         1932.0    male         white             Metastatic
# 449  TCGA-EB-A24D         1939.0    male         white    Primary solid Tumor
# 450  TCGA-EE-A3JH         1949.0    male         white             Metastatic
# 451  TCGA-D3-A8GJ         1976.0    male         white             Metastatic
# 452  TCGA-D9-A4Z6         1958.0    male         white             Metastatic
# 453  TCGA-D3-A3CE         1927.0  female         white             Metastatic
# 454  TCGA-D3-A5GU         1966.0    male         white             Metastatic
# 455  TCGA-EE-A2MP         1957.0  female         white             Metastatic
# 456  TCGA-EE-A3AC         1962.0    male         white             Metastatic
# 457  TCGA-ER-A2NE         1968.0    male         white             Metastatic
# 458  TCGA-D3-A1Q4         1950.0  female         white             Metastatic
# 459  TCGA-FS-A1Z7         1986.0    male         white             Metastatic
# 460  TCGA-IH-A3EA         1947.0    male         white    Primary solid Tumor
# 461  TCGA-EB-A6R0         1954.0  female         white    Primary solid Tumor
# 462  TCGA-EB-A4P0         1930.0    male         white    Primary solid Tumor
# 463  TCGA-FS-A4F5         1928.0  female         white             Metastatic
# 464  TCGA-DA-A95W         1959.0    male         white             Metastatic
# 465  TCGA-EE-A2MD         1946.0    male         white             Metastatic
# 466  TCGA-EE-A29H         1949.0  female         white             Metastatic
# 467  TCGA-GN-A26D         1936.0  female         white             Metastatic
# 468  TCGA-D3-A8GI         1940.0    male         white             Metastatic
# 469  TCGA-D3-A2JD         1949.0    male         white             Metastatic
# 470  TCGA-EB-A5UN         1960.0    male         white             Metastatic
# 471  TCGA-EB-A3HV         1974.0    male         white    Primary solid Tumor
#
#       tumor_stage  age_at_diagnosis vital_status  months_to_death  \
# 0         stage i             23.03         dead           261.58
# 1       stage iii             71.04         dead            69.33
# 2        stage ib             74.23        alive              NaN
# 3        stage ia             71.88        alive              NaN
# 4      stage iiic             61.39         dead            62.17
# 5       stage iii             54.27         dead            50.08
# 6       stage iia             40.28        alive              NaN
# 7       stage iib             83.37         dead           159.17
# 8    not reported             51.45        alive              NaN
# 9        stage ii             68.05         dead            60.67
# 10       stage ii             72.51        alive              NaN
# 11     stage iiic             75.15         dead            60.25
# 12      stage iic             69.58        alive              NaN
# 13      stage iic             76.96        alive              NaN
# 14      stage iic             90.06        alive              NaN
# 15      stage iic             66.38        alive              NaN
# 16       stage ib             46.87        alive              NaN
# 17        stage 0             48.73         dead            68.17
# 18     stage iiib             39.00        alive              NaN
# 19      stage iia             82.98        alive              NaN
# 20      stage iib             85.78        alive              NaN
# 21     stage iiic             50.58         dead            15.83
# 22      stage iic             68.72         dead            35.83
# 23       stage iv             54.06         dead            16.33
# 24      stage iii             23.66        alive              NaN
# 25     stage iiib             80.04        alive              NaN
# 26      stage iib             62.28        alive              NaN
# 27      stage iic             77.57        alive              NaN
# 28       stage ib             55.41        alive              NaN
# 29     stage iiic             78.55        alive              NaN
# ..            ...               ...          ...              ...
# 442      stage iv             51.32         dead            22.50
# 443    stage iiic             63.68        alive              NaN
# 444       stage i             34.87        alive              NaN
# 445    stage iiib             46.33         dead           167.00
# 446     stage iib             57.38        alive              NaN
# 447      stage iv             40.47        alive              NaN
# 448      stage ii             64.96        alive              NaN
# 449    stage iiib             72.44        alive              NaN
# 450      stage ib             54.39        alive              NaN
# 451      stage ii             18.31        alive              NaN
# 452    stage iiic             54.99         dead            46.75
# 453     stage iii             74.95         dead           152.67
# 454      stage ib             36.43        alive              NaN
# 455       stage i             34.18        alive              NaN
# 456     stage iii             47.45        alive              NaN
# 457       stage 0             39.07         dead            51.08
# 458    stage iiic             53.94        alive              NaN
# 459    stage iiic             19.98         dead            19.75
# 460     stage iic             61.85        alive              NaN
# 461     stage iic             58.54         dead            50.67
# 462     stage iic             82.81         dead            27.17
# 463      stage ib             77.84         dead            72.83
# 464    stage iiib             52.34        alive              NaN
# 465      stage ii             52.97         dead           119.83
# 466      stage ia             59.05        alive              NaN
# 467     stage iic             72.59         dead           121.67
# 468      stage ia             68.68         dead           148.33
# 469    stage iiic             58.74         dead            30.08
# 470     stage iic             49.93        alive              NaN
# 471     stage iic             37.57        alive              NaN
#
#      months_to_last_follow_up
# 0                         NaN
# 1                         NaN
# 2                      318.83
# 3                      135.00
# 4                         NaN
# 5                         NaN
# 6                      201.92
# 7                         NaN
# 8                      937.67
# 9                         NaN
# 10                     411.83
# 11                        NaN
# 12                     220.33
# 13                      40.83
# 14                      21.83
# 15                      34.50
# 16                     293.92
# 17                        NaN
# 18                     114.83
# 19                     168.50
# 20                      51.17
# 21                       7.75
# 22                      25.17
# 23                      16.33
# 24                     452.00
# 25                      45.50
# 26                       5.17
# 27                      36.67
# 28                     230.42
# 29                      49.17
# ..                        ...
# 442                       NaN
# 443                     47.58
# 444                    558.25
# 445                       NaN
# 446                    149.50
# 447                     37.83
# 448                    555.50
# 449                     53.75
# 450                    340.50
# 451                    611.83
# 452                     28.17
# 453                       NaN
# 454                    317.33
# 455                    630.25
# 456                    162.33
# 457                       NaN
# 458                    284.00
# 459                       NaN
# 460                     43.67
# 461                     38.92
# 462                     -0.17
# 463                       NaN
# 464                     63.75
# 465                       NaN
# 466                    163.83
# 467                    100.33
# 468                       NaN
# 469                       NaN
# 470                    149.33
# 471                      3.25
#
# [472 rows x 10 columns]

# %%
#remove healthy patients from clinical_short
clinical_short_for_export = clinical_short[clinical_short.definition != 'Solid Tissue Normal']

# %%
#Another quick sanity check.
clinical_short_for_export['definition'].unique()
# Out:
# array(['Metastatic', 'Primary solid Tumor', 'Additional Metastatic'],
#       dtype=object)

# %%
clinical_short_for_export.to_csv('clinical_short.csv' , sep = '\t')

# %%
# need to relaod files again and store them in a new variable in order to extract gzip files 
files2 = os.listdir()
low_memory = False
for files2 in files2: 
    if (files2.endswith('.gz')):
        somatic = pd.read_csv(files2, sep = '\t' , compression = 'gzip', comment = '#')
        print(somatic.head(10))
# Out:
#   Hugo_Symbol  Entrez_Gene_Id Center NCBI_Build Chromosome  Start_Position  \
# 0        RER1           11079    BCM     GRCh38       chr1         2402218
# 1       WASF2           10163    BCM     GRCh38       chr1        27410171
# 2       MACF1           23499    BCM     GRCh38       chr1        39455094
# 3       KDM4A            9682    BCM     GRCh38       chr1        43669220
# 4        NFIA            4774    BCM     GRCh38       chr1        61088433
# 5        NFIA            4774    BCM     GRCh38       chr1        61088434
# 6      FAM72C          554282    BCM     GRCh38       chr1       143975118
# 7     GATAD2B           57459    BCM     GRCh38       chr1       153828260
# 8       DCST1          149095    BCM     GRCh38       chr1       155050883
# 9       CADM3           57863    BCM     GRCh38       chr1       159200836
#
#    End_Position Strand Variant_Classification Variant_Type  \
# 0       2402219      +           In_Frame_Ins          INS
# 1      27410171      +      Missense_Mutation          SNP
# 2      39455094      +      Missense_Mutation          SNP
# 3      43669220      +                 Silent          SNP
# 4      61088433      +                 Silent          SNP
# 5      61088434      +      Missense_Mutation          SNP
# 6     143975120      +                5'Flank          DEL
# 7     153828260      +      Nonsense_Mutation          SNP
# 8     155050883      +                  3'UTR          SNP
# 9     159200836      +      Missense_Mutation          SNP
#
#            ...                      FILTER         CONTEXT  \
# 0          ...                        PASS     GGCTACCAAGG
# 1          ...                        PASS     GTCCAGCCAAA
# 2          ...                        PASS     GAGCATCAGGT
# 3          ...            panel_of_normals     ATGACGGAGTG
# 4          ...                        PASS     TGTGTTCTTTC
# 5          ...                        PASS     GTGTTCTTTCC
# 6          ...                        PASS  AGGATAAGGAGATC
# 7          ...                        PASS     TCGCTTTGCCA
# 8          ...                        PASS     CTGCTCGCTCT
# 9          ...                        PASS     GCTCCGACGAT
#
#                              src_vcf_id                        tumor_bam_uuid  \
# 0  b453708b-e945-46cb-a496-d7a2d5da83c8  d0f86a38-5296-406a-bf7d-1ac9ff2628af
# 1  b453708b-e945-46cb-a496-d7a2d5da83c8  d0f86a38-5296-406a-bf7d-1ac9ff2628af
# 2  b453708b-e945-46cb-a496-d7a2d5da83c8  d0f86a38-5296-406a-bf7d-1ac9ff2628af
# 3  b453708b-e945-46cb-a496-d7a2d5da83c8  d0f86a38-5296-406a-bf7d-1ac9ff2628af
# 4  b453708b-e945-46cb-a496-d7a2d5da83c8  d0f86a38-5296-406a-bf7d-1ac9ff2628af
# 5  b453708b-e945-46cb-a496-d7a2d5da83c8  d0f86a38-5296-406a-bf7d-1ac9ff2628af
# 6  b453708b-e945-46cb-a496-d7a2d5da83c8  d0f86a38-5296-406a-bf7d-1ac9ff2628af
# 7  b453708b-e945-46cb-a496-d7a2d5da83c8  d0f86a38-5296-406a-bf7d-1ac9ff2628af
# 8  b453708b-e945-46cb-a496-d7a2d5da83c8  d0f86a38-5296-406a-bf7d-1ac9ff2628af
# 9  b453708b-e945-46cb-a496-d7a2d5da83c8  d0f86a38-5296-406a-bf7d-1ac9ff2628af
#
#                         normal_bam_uuid                               case_id  \
# 0  11bb6c32-0ed0-4228-a2f4-ccc148d00530  92b67ca9-6c82-463e-9cc5-685a1d02ea3e
# 1  11bb6c32-0ed0-4228-a2f4-ccc148d00530  92b67ca9-6c82-463e-9cc5-685a1d02ea3e
# 2  11bb6c32-0ed0-4228-a2f4-ccc148d00530  92b67ca9-6c82-463e-9cc5-685a1d02ea3e
# 3  11bb6c32-0ed0-4228-a2f4-ccc148d00530  92b67ca9-6c82-463e-9cc5-685a1d02ea3e
# 4  11bb6c32-0ed0-4228-a2f4-ccc148d00530  92b67ca9-6c82-463e-9cc5-685a1d02ea3e
# 5  11bb6c32-0ed0-4228-a2f4-ccc148d00530  92b67ca9-6c82-463e-9cc5-685a1d02ea3e
# 6  11bb6c32-0ed0-4228-a2f4-ccc148d00530  92b67ca9-6c82-463e-9cc5-685a1d02ea3e
# 7  11bb6c32-0ed0-4228-a2f4-ccc148d00530  92b67ca9-6c82-463e-9cc5-685a1d02ea3e
# 8  11bb6c32-0ed0-4228-a2f4-ccc148d00530  92b67ca9-6c82-463e-9cc5-685a1d02ea3e
# 9  11bb6c32-0ed0-4228-a2f4-ccc148d00530  92b67ca9-6c82-463e-9cc5-685a1d02ea3e
#
#   GDC_FILTER       COSMIC  MC3_Overlap  GDC_Validation_Status
# 0        NaN          NaN        False                Unknown
# 1        NaN          NaN         True                Unknown
# 2        NaN          NaN         True                Unknown
# 3    gdc_pon  COSM3805346         True                Unknown
# 4        NaN          NaN         True                Unknown
# 5        NaN          NaN         True                Unknown
# 6        NaN          NaN        False                Unknown
# 7        NaN          NaN         True                Unknown
# 8        NaN          NaN         True                Unknown
# 9        NaN   COSM159709         True                Unknown
#
# [10 rows x 120 columns]
#   Hugo_Symbol  Entrez_Gene_Id Center NCBI_Build Chromosome  Start_Position  \
# 0       USP24           23358  WUGSC     GRCh38       chr1        55159655
# 1      ERICH3          127254  WUGSC     GRCh38       chr1        74571494
# 2      KIF26B           55083  WUGSC     GRCh38       chr1       245419680
# 3       USP34            9736  WUGSC     GRCh38       chr2        61189055
# 4      ANTXR1           84168  WUGSC     GRCh38       chr2        69245305
# 5       SCN9A            6335  WUGSC     GRCh38       chr2       166199365
# 6         FN1            2335  WUGSC     GRCh38       chr2       215397809
# 7      SPHKAP           80309  WUGSC     GRCh38       chr2       228016738
# 8        HRH1            3269  WUGSC     GRCh38       chr3        11259653
# 9       LRRC2           79442  WUGSC     GRCh38       chr3        46519054
#
#    End_Position Strand Variant_Classification Variant_Type  \
# 0      55159655      +      Missense_Mutation          SNP
# 1      74571494      +      Missense_Mutation          SNP
# 2     245419680      +                 Silent          SNP
# 3      61189055      +                 Silent          SNP
# 4      69245305      +                 Silent          SNP
# 5     166199365      +                 Silent          SNP
# 6     215397809      +      Nonsense_Mutation          SNP
# 7     228016738      +      Missense_Mutation          SNP
# 8      11259653      +      Missense_Mutation          SNP
# 9      46519054      +      Missense_Mutation          SNP
#
#            ...                     FILTER      CONTEXT  \
# 0          ...           panel_of_normals  CTGGATTGTAG
# 1          ...                       PASS  TTCCTCTACCA
# 2          ...                       PASS  GCCTCGCAGGG
# 3          ...                       PASS  AAAGCGAGTGC
# 4          ...                       PASS  TCCTCGCCGCC
# 5          ...                       PASS  AGTATGACTGC
# 6          ...                       PASS  CACTTCTCGTG
# 7          ...                       PASS  TCTTTCCTCGG
# 8          ...                       PASS  TGCTCATGCTC
# 9          ...           panel_of_normals  AGCTGGGAACA
#
#                              src_vcf_id                        tumor_bam_uuid  \
# 0  d083d669-6646-463b-853e-c58da8d06439  4374e19d-c5e7-49cf-8707-05ae5aeb7369
# 1  d083d669-6646-463b-853e-c58da8d06439  4374e19d-c5e7-49cf-8707-05ae5aeb7369
# 2  d083d669-6646-463b-853e-c58da8d06439  4374e19d-c5e7-49cf-8707-05ae5aeb7369
# 3  d083d669-6646-463b-853e-c58da8d06439  4374e19d-c5e7-49cf-8707-05ae5aeb7369
# 4  d083d669-6646-463b-853e-c58da8d06439  4374e19d-c5e7-49cf-8707-05ae5aeb7369
# 5  d083d669-6646-463b-853e-c58da8d06439  4374e19d-c5e7-49cf-8707-05ae5aeb7369
# 6  d083d669-6646-463b-853e-c58da8d06439  4374e19d-c5e7-49cf-8707-05ae5aeb7369
# 7  d083d669-6646-463b-853e-c58da8d06439  4374e19d-c5e7-49cf-8707-05ae5aeb7369
# 8  d083d669-6646-463b-853e-c58da8d06439  4374e19d-c5e7-49cf-8707-05ae5aeb7369
# 9  d083d669-6646-463b-853e-c58da8d06439  4374e19d-c5e7-49cf-8707-05ae5aeb7369
#
#                         normal_bam_uuid                               case_id  \
# 0  aadee87c-6a68-4580-bd10-64ac273b1e3d  0130d616-885e-4a6c-9d03-2f17dd692a05
# 1  aadee87c-6a68-4580-bd10-64ac273b1e3d  0130d616-885e-4a6c-9d03-2f17dd692a05
# 2  aadee87c-6a68-4580-bd10-64ac273b1e3d  0130d616-885e-4a6c-9d03-2f17dd692a05
# 3  aadee87c-6a68-4580-bd10-64ac273b1e3d  0130d616-885e-4a6c-9d03-2f17dd692a05
# 4  aadee87c-6a68-4580-bd10-64ac273b1e3d  0130d616-885e-4a6c-9d03-2f17dd692a05
# 5  aadee87c-6a68-4580-bd10-64ac273b1e3d  0130d616-885e-4a6c-9d03-2f17dd692a05
# 6  aadee87c-6a68-4580-bd10-64ac273b1e3d  0130d616-885e-4a6c-9d03-2f17dd692a05
# 7  aadee87c-6a68-4580-bd10-64ac273b1e3d  0130d616-885e-4a6c-9d03-2f17dd692a05
# 8  aadee87c-6a68-4580-bd10-64ac273b1e3d  0130d616-885e-4a6c-9d03-2f17dd692a05
# 9  aadee87c-6a68-4580-bd10-64ac273b1e3d  0130d616-885e-4a6c-9d03-2f17dd692a05
#
#                GDC_FILTER                   COSMIC  MC3_Overlap  \
# 0  common_in_exac;gdc_pon                      NaN         True
# 1                     NaN              COSM1474194         True
# 2                     NaN  COSM1473725;COSM1473726         True
# 3                     NaN              COSM1483177         True
# 4                     NaN              COSM1409122         True
# 5                     NaN  COSM1482144;COSM4814664         True
# 6                     NaN  COSM1482746;COSM1482747         True
# 7                     NaN  COSM1482832;COSM1482833         True
# 8                     NaN              COSM1484451         True
# 9                 gdc_pon              COSM1485224         True
#
#   GDC_Validation_Status
# 0               Unknown
# 1               Unknown
# 2               Unknown
# 3               Unknown
# 4               Unknown
# 5               Unknown
# 6               Unknown
# 7               Unknown
# 8               Unknown
# 9               Unknown
#
# [10 rows x 120 columns]
#   Hugo_Symbol  Entrez_Gene_Id Center NCBI_Build Chromosome  Start_Position  \
# 0       OR8B4          283162  WUGSC     GRCh38      chr11       124424661
# 1         CD4             920  WUGSC     GRCh38      chr12         6820166
# 2     CAPRIN2           65981  WUGSC     GRCh38      chr12        30753693
# 3       CHRM5            1133  WUGSC     GRCh38      chr15        34064542
# 4      SCAMP5          192683  WUGSC     GRCh38      chr15        75018463
# 5       CEBPA            1050  WUGSC     GRCh38      chr19        33301484
# 6      CTNNA2            1496     BI     GRCh38       chr2        80589331
# 7       IL12A            3592     BI     GRCh38       chr3       159995603
# 8      POLR2B            5431     BI     GRCh38       chr4        57017215
# 9       RWDD4          201965     BI     GRCh38       chr4       183655953
#
#    End_Position Strand Variant_Classification Variant_Type  \
# 0     124424661      +      Missense_Mutation          SNP
# 1       6820166      +                  3'UTR          SNP
# 2      30753693      +      Nonsense_Mutation          SNP
# 3      34064542      +                  3'UTR          SNP
# 4      75018463      +                 Silent          SNP
# 5      33301485      +           In_Frame_Ins          INS
# 6      80589331      +      Nonsense_Mutation          SNP
# 7     159995603      +                  3'UTR          SNP
# 8      57017215      +      Missense_Mutation          SNP
# 9     183655953      +                 Silent          SNP
#
#            ...                         FILTER      CONTEXT  \
# 0          ...                           PASS  ACAGAGATCTA
# 1          ...                           PASS  TGGCTAGTGGT
# 2          ...           alt_allele_in_normal  TAGACCACTCC
# 3          ...                           PASS  ATGCCAGGGGA
# 4          ...                           PASS  GGCTCGGCGGT
# 5          ...                           PASS  CTGCTGCGTCT
# 6          ...                           PASS  AGGAGGAGAAG
# 7          ...               panel_of_normals  ACTTTGAAATG
# 8          ...                           PASS  CATCTATTATT
# 9          ...                           PASS  GCTTCTAGTTC
#
#                              src_vcf_id                        tumor_bam_uuid  \
# 0  2c6f9ca6-923f-4ed7-9846-bdfe28776650  bb47da9c-2365-4a64-909a-89d74c8159a7
# 1  2c6f9ca6-923f-4ed7-9846-bdfe28776650  bb47da9c-2365-4a64-909a-89d74c8159a7
# 2  2c6f9ca6-923f-4ed7-9846-bdfe28776650  bb47da9c-2365-4a64-909a-89d74c8159a7
# 3  2c6f9ca6-923f-4ed7-9846-bdfe28776650  bb47da9c-2365-4a64-909a-89d74c8159a7
# 4  2c6f9ca6-923f-4ed7-9846-bdfe28776650  bb47da9c-2365-4a64-909a-89d74c8159a7
# 5  2c6f9ca6-923f-4ed7-9846-bdfe28776650  bb47da9c-2365-4a64-909a-89d74c8159a7
# 6  74d0baf8-32b6-4f07-a6bd-ab22910f7324  052bcf45-4e0c-4022-a82e-edd4b65f50a4
# 7  74d0baf8-32b6-4f07-a6bd-ab22910f7324  052bcf45-4e0c-4022-a82e-edd4b65f50a4
# 8  74d0baf8-32b6-4f07-a6bd-ab22910f7324  052bcf45-4e0c-4022-a82e-edd4b65f50a4
# 9  74d0baf8-32b6-4f07-a6bd-ab22910f7324  052bcf45-4e0c-4022-a82e-edd4b65f50a4
#
#                         normal_bam_uuid                               case_id  \
# 0  6a1e64a7-aea3-4c2e-8f62-abfc94f35b62  b5cbd66f-948d-45a3-af3b-f17e2b35d85e
# 1  6a1e64a7-aea3-4c2e-8f62-abfc94f35b62  b5cbd66f-948d-45a3-af3b-f17e2b35d85e
# 2  6a1e64a7-aea3-4c2e-8f62-abfc94f35b62  b5cbd66f-948d-45a3-af3b-f17e2b35d85e
# 3  6a1e64a7-aea3-4c2e-8f62-abfc94f35b62  b5cbd66f-948d-45a3-af3b-f17e2b35d85e
# 4  6a1e64a7-aea3-4c2e-8f62-abfc94f35b62  b5cbd66f-948d-45a3-af3b-f17e2b35d85e
# 5  6a1e64a7-aea3-4c2e-8f62-abfc94f35b62  b5cbd66f-948d-45a3-af3b-f17e2b35d85e
# 6  0414fcbb-352d-41d6-a8cf-0d2f5eb7f3e4  c1f908ce-f6d5-4557-a4bf-956b71b8bf61
# 7  0414fcbb-352d-41d6-a8cf-0d2f5eb7f3e4  c1f908ce-f6d5-4557-a4bf-956b71b8bf61
# 8  0414fcbb-352d-41d6-a8cf-0d2f5eb7f3e4  c1f908ce-f6d5-4557-a4bf-956b71b8bf61
# 9  0414fcbb-352d-41d6-a8cf-0d2f5eb7f3e4  c1f908ce-f6d5-4557-a4bf-956b71b8bf61
#
#          GDC_FILTER  COSMIC  MC3_Overlap GDC_Validation_Status
# 0          wga_pair     NaN        False               Unknown
# 1          wga_pair     NaN        False               Unknown
# 2          wga_pair     NaN        False                 Valid
# 3          wga_pair     NaN        False               Unknown
# 4          wga_pair     NaN        False               Unknown
# 5          wga_pair     NaN        False                 Valid
# 6          wga_pair     NaN         True               Unknown
# 7  gdc_pon;wga_pair     NaN         True               Unknown
# 8          wga_pair     NaN         True               Unknown
# 9          wga_pair     NaN         True               Unknown
#
# [10 rows x 120 columns]
#   Hugo_Symbol  Entrez_Gene_Id Center NCBI_Build Chromosome  Start_Position  \
# 0      CAMTA1           23261     BI     GRCh38       chr1         7663407
# 1         C8B             732     BI     GRCh38       chr1        56956798
# 2      ADGRL4           64123     BI     GRCh38       chr1        78921709
# 3    ARHGAP29            9411     BI     GRCh38       chr1        94188873
# 4      LRRC39          127495     BI     GRCh38       chr1       100155171
# 5       NTNG1           22854     BI     GRCh38       chr1       107148685
# 6     PRPF38B           55119     BI     GRCh38       chr1       108699496
# 7     SLC6A17          388662     BI     GRCh38       chr1       110198448
# 8       MEX3A           92312     BI     GRCh38       chr1       156076542
# 9       INSRR            3645     BI     GRCh38       chr1       156846588
#
#    End_Position Strand Variant_Classification Variant_Type  \
# 0       7663407      +      Missense_Mutation          SNP
# 1      56956798      +      Missense_Mutation          SNP
# 2      78921709      +                 Silent          SNP
# 3      94188873      +      Missense_Mutation          SNP
# 4     100155171      +      Missense_Mutation          SNP
# 5     107148685      +      Missense_Mutation          SNP
# 6     108699496      +      Missense_Mutation          SNP
# 7     110198448      +                  3'UTR          SNP
# 8     156076542      +                  3'UTR          SNP
# 9     156846588      +      Missense_Mutation          SNP
#
#            ...                      FILTER      CONTEXT  \
# 0          ...                        PASS  CATCTCGCCCA
# 1          ...                        PASS  CACATCGCACT
# 2          ...            panel_of_normals  CAGCCCTCTGA
# 3          ...                        PASS  AGATTCGCTGC
# 4          ...                        PASS  CATTTCGTTGC
# 5          ...                        PASS  TTATGATTTGT
# 6          ...                        PASS  ATAAGGAAAGA
# 7          ...                        PASS  GACCACTGCCC
# 8          ...                        PASS  CCAGTGGAGTG
# 9          ...                        PASS  AGTGGTTAGCG
#
#                              src_vcf_id                        tumor_bam_uuid  \
# 0  f944eaa8-8260-411c-b875-824f27ab961c  e0e25c3a-0f0c-4d60-b1d5-9938d3e1c4d0
# 1  f944eaa8-8260-411c-b875-824f27ab961c  e0e25c3a-0f0c-4d60-b1d5-9938d3e1c4d0
# 2  f944eaa8-8260-411c-b875-824f27ab961c  e0e25c3a-0f0c-4d60-b1d5-9938d3e1c4d0
# 3  f944eaa8-8260-411c-b875-824f27ab961c  e0e25c3a-0f0c-4d60-b1d5-9938d3e1c4d0
# 4  f944eaa8-8260-411c-b875-824f27ab961c  e0e25c3a-0f0c-4d60-b1d5-9938d3e1c4d0
# 5  f944eaa8-8260-411c-b875-824f27ab961c  e0e25c3a-0f0c-4d60-b1d5-9938d3e1c4d0
# 6  f944eaa8-8260-411c-b875-824f27ab961c  e0e25c3a-0f0c-4d60-b1d5-9938d3e1c4d0
# 7  f944eaa8-8260-411c-b875-824f27ab961c  e0e25c3a-0f0c-4d60-b1d5-9938d3e1c4d0
# 8  f944eaa8-8260-411c-b875-824f27ab961c  e0e25c3a-0f0c-4d60-b1d5-9938d3e1c4d0
# 9  f944eaa8-8260-411c-b875-824f27ab961c  e0e25c3a-0f0c-4d60-b1d5-9938d3e1c4d0
#
#                         normal_bam_uuid                               case_id  \
# 0  4ba835c3-36e8-4285-bffc-187fa3c048cb  69c0ef46-3117-46f3-b36e-581eb03eb829
# 1  4ba835c3-36e8-4285-bffc-187fa3c048cb  69c0ef46-3117-46f3-b36e-581eb03eb829
# 2  4ba835c3-36e8-4285-bffc-187fa3c048cb  69c0ef46-3117-46f3-b36e-581eb03eb829
# 3  4ba835c3-36e8-4285-bffc-187fa3c048cb  69c0ef46-3117-46f3-b36e-581eb03eb829
# 4  4ba835c3-36e8-4285-bffc-187fa3c048cb  69c0ef46-3117-46f3-b36e-581eb03eb829
# 5  4ba835c3-36e8-4285-bffc-187fa3c048cb  69c0ef46-3117-46f3-b36e-581eb03eb829
# 6  4ba835c3-36e8-4285-bffc-187fa3c048cb  69c0ef46-3117-46f3-b36e-581eb03eb829
# 7  4ba835c3-36e8-4285-bffc-187fa3c048cb  69c0ef46-3117-46f3-b36e-581eb03eb829
# 8  4ba835c3-36e8-4285-bffc-187fa3c048cb  69c0ef46-3117-46f3-b36e-581eb03eb829
# 9  4ba835c3-36e8-4285-bffc-187fa3c048cb  69c0ef46-3117-46f3-b36e-581eb03eb829
#
#        GDC_FILTER                                           COSMIC  \
# 0             NaN                                        COSM43045
# 1             NaN                                      COSM3491224
# 2         gdc_pon                                      COSM3492631
# 3             NaN                                      COSM3493540
# 4  common_in_exac                          COSM3470289;COSM4906093
# 5             NaN  COSM3470623;COSM3470624;COSM3470625;COSM3470626
# 6             NaN                                      COSM3470698
# 7             NaN                                              NaN
# 8             NaN                                              NaN
# 9             NaN                          COSM3475449;COSM3475450
#
#    MC3_Overlap  GDC_Validation_Status
# 0         True                Unknown
# 1         True                Unknown
# 2         True                Unknown
# 3         True                Unknown
# 4         True                Unknown
# 5         True                Unknown
# 6        False                Unknown
# 7         True                Unknown
# 8         True                Unknown
# 9         True                Unknown
#
# [10 rows x 120 columns]

# %%
somatic.head()
# Out:
#   Hugo_Symbol  Entrez_Gene_Id Center NCBI_Build Chromosome  Start_Position  \
# 0      CAMTA1           23261     BI     GRCh38       chr1         7663407
# 1         C8B             732     BI     GRCh38       chr1        56956798
# 2      ADGRL4           64123     BI     GRCh38       chr1        78921709
# 3    ARHGAP29            9411     BI     GRCh38       chr1        94188873
# 4      LRRC39          127495     BI     GRCh38       chr1       100155171
#
#    End_Position Strand Variant_Classification Variant_Type  \
# 0       7663407      +      Missense_Mutation          SNP
# 1      56956798      +      Missense_Mutation          SNP
# 2      78921709      +                 Silent          SNP
# 3      94188873      +      Missense_Mutation          SNP
# 4     100155171      +      Missense_Mutation          SNP
#
#            ...                      FILTER      CONTEXT  \
# 0          ...                        PASS  CATCTCGCCCA
# 1          ...                        PASS  CACATCGCACT
# 2          ...            panel_of_normals  CAGCCCTCTGA
# 3          ...                        PASS  AGATTCGCTGC
# 4          ...                        PASS  CATTTCGTTGC
#
#                              src_vcf_id                        tumor_bam_uuid  \
# 0  f944eaa8-8260-411c-b875-824f27ab961c  e0e25c3a-0f0c-4d60-b1d5-9938d3e1c4d0
# 1  f944eaa8-8260-411c-b875-824f27ab961c  e0e25c3a-0f0c-4d60-b1d5-9938d3e1c4d0
# 2  f944eaa8-8260-411c-b875-824f27ab961c  e0e25c3a-0f0c-4d60-b1d5-9938d3e1c4d0
# 3  f944eaa8-8260-411c-b875-824f27ab961c  e0e25c3a-0f0c-4d60-b1d5-9938d3e1c4d0
# 4  f944eaa8-8260-411c-b875-824f27ab961c  e0e25c3a-0f0c-4d60-b1d5-9938d3e1c4d0
#
#                         normal_bam_uuid                               case_id  \
# 0  4ba835c3-36e8-4285-bffc-187fa3c048cb  69c0ef46-3117-46f3-b36e-581eb03eb829
# 1  4ba835c3-36e8-4285-bffc-187fa3c048cb  69c0ef46-3117-46f3-b36e-581eb03eb829
# 2  4ba835c3-36e8-4285-bffc-187fa3c048cb  69c0ef46-3117-46f3-b36e-581eb03eb829
# 3  4ba835c3-36e8-4285-bffc-187fa3c048cb  69c0ef46-3117-46f3-b36e-581eb03eb829
# 4  4ba835c3-36e8-4285-bffc-187fa3c048cb  69c0ef46-3117-46f3-b36e-581eb03eb829
#
#        GDC_FILTER                   COSMIC  MC3_Overlap  GDC_Validation_Status
# 0             NaN                COSM43045         True                Unknown
# 1             NaN              COSM3491224         True                Unknown
# 2         gdc_pon              COSM3492631         True                Unknown
# 3             NaN              COSM3493540         True                Unknown
# 4  common_in_exac  COSM3470289;COSM4906093         True                Unknown
#
# [5 rows x 120 columns]

# %%
#Export somatic data to .xlsx
testingz = somatic.to_csv('somatic.csv', sep = '\t')

# %%
low_memory = False
brca = pd.read_csv('BRCA.somatic.maf.gz' , sep = '\t' , compression = 'gzip' , comment = '#')

# %%
brca.head(10)
# Out:
#   Hugo_Symbol  Entrez_Gene_Id Center NCBI_Build Chromosome  Start_Position  \
# 0       USP24           23358  WUGSC     GRCh38       chr1        55159655
# 1      ERICH3          127254  WUGSC     GRCh38       chr1        74571494
# 2      KIF26B           55083  WUGSC     GRCh38       chr1       245419680
# 3       USP34            9736  WUGSC     GRCh38       chr2        61189055
# 4      ANTXR1           84168  WUGSC     GRCh38       chr2        69245305
# 5       SCN9A            6335  WUGSC     GRCh38       chr2       166199365
# 6         FN1            2335  WUGSC     GRCh38       chr2       215397809
# 7      SPHKAP           80309  WUGSC     GRCh38       chr2       228016738
# 8        HRH1            3269  WUGSC     GRCh38       chr3        11259653
# 9       LRRC2           79442  WUGSC     GRCh38       chr3        46519054
#
#    End_Position Strand Variant_Classification Variant_Type  \
# 0      55159655      +      Missense_Mutation          SNP
# 1      74571494      +      Missense_Mutation          SNP
# 2     245419680      +                 Silent          SNP
# 3      61189055      +                 Silent          SNP
# 4      69245305      +                 Silent          SNP
# 5     166199365      +                 Silent          SNP
# 6     215397809      +      Nonsense_Mutation          SNP
# 7     228016738      +      Missense_Mutation          SNP
# 8      11259653      +      Missense_Mutation          SNP
# 9      46519054      +      Missense_Mutation          SNP
#
#            ...                     FILTER      CONTEXT  \
# 0          ...           panel_of_normals  CTGGATTGTAG
# 1          ...                       PASS  TTCCTCTACCA
# 2          ...                       PASS  GCCTCGCAGGG
# 3          ...                       PASS  AAAGCGAGTGC
# 4          ...                       PASS  TCCTCGCCGCC
# 5          ...                       PASS  AGTATGACTGC
# 6          ...                       PASS  CACTTCTCGTG
# 7          ...                       PASS  TCTTTCCTCGG
# 8          ...                       PASS  TGCTCATGCTC
# 9          ...           panel_of_normals  AGCTGGGAACA
#
#                              src_vcf_id                        tumor_bam_uuid  \
# 0  d083d669-6646-463b-853e-c58da8d06439  4374e19d-c5e7-49cf-8707-05ae5aeb7369
# 1  d083d669-6646-463b-853e-c58da8d06439  4374e19d-c5e7-49cf-8707-05ae5aeb7369
# 2  d083d669-6646-463b-853e-c58da8d06439  4374e19d-c5e7-49cf-8707-05ae5aeb7369
# 3  d083d669-6646-463b-853e-c58da8d06439  4374e19d-c5e7-49cf-8707-05ae5aeb7369
# 4  d083d669-6646-463b-853e-c58da8d06439  4374e19d-c5e7-49cf-8707-05ae5aeb7369
# 5  d083d669-6646-463b-853e-c58da8d06439  4374e19d-c5e7-49cf-8707-05ae5aeb7369
# 6  d083d669-6646-463b-853e-c58da8d06439  4374e19d-c5e7-49cf-8707-05ae5aeb7369
# 7  d083d669-6646-463b-853e-c58da8d06439  4374e19d-c5e7-49cf-8707-05ae5aeb7369
# 8  d083d669-6646-463b-853e-c58da8d06439  4374e19d-c5e7-49cf-8707-05ae5aeb7369
# 9  d083d669-6646-463b-853e-c58da8d06439  4374e19d-c5e7-49cf-8707-05ae5aeb7369
#
#                         normal_bam_uuid                               case_id  \
# 0  aadee87c-6a68-4580-bd10-64ac273b1e3d  0130d616-885e-4a6c-9d03-2f17dd692a05
# 1  aadee87c-6a68-4580-bd10-64ac273b1e3d  0130d616-885e-4a6c-9d03-2f17dd692a05
# 2  aadee87c-6a68-4580-bd10-64ac273b1e3d  0130d616-885e-4a6c-9d03-2f17dd692a05
# 3  aadee87c-6a68-4580-bd10-64ac273b1e3d  0130d616-885e-4a6c-9d03-2f17dd692a05
# 4  aadee87c-6a68-4580-bd10-64ac273b1e3d  0130d616-885e-4a6c-9d03-2f17dd692a05
# 5  aadee87c-6a68-4580-bd10-64ac273b1e3d  0130d616-885e-4a6c-9d03-2f17dd692a05
# 6  aadee87c-6a68-4580-bd10-64ac273b1e3d  0130d616-885e-4a6c-9d03-2f17dd692a05
# 7  aadee87c-6a68-4580-bd10-64ac273b1e3d  0130d616-885e-4a6c-9d03-2f17dd692a05
# 8  aadee87c-6a68-4580-bd10-64ac273b1e3d  0130d616-885e-4a6c-9d03-2f17dd692a05
# 9  aadee87c-6a68-4580-bd10-64ac273b1e3d  0130d616-885e-4a6c-9d03-2f17dd692a05
#
#                GDC_FILTER                   COSMIC  MC3_Overlap  \
# 0  common_in_exac;gdc_pon                      NaN         True
# 1                     NaN              COSM1474194         True
# 2                     NaN  COSM1473725;COSM1473726         True
# 3                     NaN              COSM1483177         True
# 4                     NaN              COSM1409122         True
# 5                     NaN  COSM1482144;COSM4814664         True
# 6                     NaN  COSM1482746;COSM1482747         True
# 7                     NaN  COSM1482832;COSM1482833         True
# 8                     NaN              COSM1484451         True
# 9                 gdc_pon              COSM1485224         True
#
#   GDC_Validation_Status
# 0               Unknown
# 1               Unknown
# 2               Unknown
# 3               Unknown
# 4               Unknown
# 5               Unknown
# 6               Unknown
# 7               Unknown
# 8               Unknown
# 9               Unknown
#
# [10 rows x 120 columns]

# %%
clinical["patient"].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0      TCGA-EE-A2MG
# 1      TCGA-EE-A3JD
# 2      TCGA-D3-A5GL
# 3      TCGA-EE-A2MU
# 4      TCGA-D3-A3CF
# 5      TCGA-EE-A2M8
# 6      TCGA-EE-A2GL
# 7      TCGA-GN-A268
# 8      TCGA-EE-A29T
# 9      TCGA-FS-A1ZK
# 10     TCGA-EE-A2MS
# 11     TCGA-D3-A2J9
# 12     TCGA-D3-A3CC
# 13     TCGA-BF-A5ES
# 14     TCGA-EB-A41A
# 15     TCGA-EB-A97M
# 16     TCGA-EE-A2A1
# 17     TCGA-EE-A183
# 18     TCGA-D3-A3MV
# 19     TCGA-3N-A9WC
# 20     TCGA-WE-A8K4
# 21     TCGA-D9-A4Z2
# 22     TCGA-DA-A95Y
# 23     TCGA-ER-A19J
# 24     TCGA-D3-A5GR
# 25     TCGA-WE-A8K6
# 26     TCGA-GF-A6C8
# 27     TCGA-BF-A9VF
# 28     TCGA-D3-A1QA
# 29     TCGA-EB-A551
#            ...
# 442    TCGA-ER-A19T
# 443    TCGA-FR-A7U9
# 444    TCGA-EE-A2GH
# 445    TCGA-HR-A2OH
# 446    TCGA-WE-A8ZN
# 447    TCGA-BF-AAP0
# 448    TCGA-W3-AA1W
# 449    TCGA-EB-A24D
# 450    TCGA-EE-A3JH
# 451    TCGA-D3-A8GJ
# 452    TCGA-D9-A4Z6
# 453    TCGA-D3-A3CE
# 454    TCGA-D3-A5GU
# 455    TCGA-EE-A2MP
# 456    TCGA-EE-A3AC
# 457    TCGA-ER-A2NE
# 458    TCGA-D3-A1Q4
# 459    TCGA-FS-A1Z7
# 460    TCGA-IH-A3EA
# 461    TCGA-EB-A6R0
# 462    TCGA-EB-A4P0
# 463    TCGA-FS-A4F5
# 464    TCGA-DA-A95W
# 465    TCGA-EE-A2MD
# 466    TCGA-EE-A29H
# 467    TCGA-GN-A26D
# 468    TCGA-D3-A8GI
# 469    TCGA-D3-A2JD
# 470    TCGA-EB-A5UN
# 471    TCGA-EB-A3HV
# Name: patient, Length: 472, dtype: object>
